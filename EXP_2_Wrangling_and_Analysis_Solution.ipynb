# %% [markdown]
# <a href="https://colab.research.google.com/github/SIVAGORAM/DEEPLEARNING/blob/main/EXP_2_Wrangling_and_Analysis_Solution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
%9921005015
import re
import json
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')
import urllib.request
url = 'https://raw.githubusercontent.com/MonashDataFluency/python-web-scraping/master/data/infoboxes.json'
urllib.request.urlretrieve(url, 'infoboxes.json')
with open('infoboxes.json', 'r') as file:
 wiki_data = json.load(file)
wiki_data[0]
for i in range(0,3):
 print(wiki_data[i]['products'])
 print('\n')
 regex = re.compile(r'[\w\s-]+')
 import re
rogue_words = ['unbulleted list', 'hlist', 'flat list', 'flatlist', 'plainlist', 's', 'br', '']
products = []
data = []
for x in wiki_data:
 product = x['products'].lower()
 product = product.replace(' and ', '|').replace(']]', '')
 product = re.findall(r'\w+', product)
 product = [p.strip() for p in product] # get rid of leading or trailing whitespace
 product = list(set([p for p in product if p not in rogue_words]))
 # add to data
 data.append({
 'wiki_title' : x['company_name'],
 'product' : ', '.join(product) })
 products.extend(product)
print(products)
def create_wordcloud(items, stopwords=[]):
    text = ' '.join(items)
    wordcloud = WordCloud(width=1600, height=800, margin=0, stopwords=stopwords).generate(text)
    plt.figure(figsize=(20, 10))  # set the final figure size
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis("off")
    plt.tight_layout(pad=0)  # no padding
    plt.show()  # display plot

create_wordcloud(products)
import re
for i in range(0,5):
 print(wiki_data[i]['industry'])
 industries = []
for i, x in enumerate(wiki_data):
 industry = x['industry'].lower()
 industry = industry.replace(' and ', '|').replace(']]', '')
 industry = re.findall(r'\w+', industry)
 industry = [i.strip() for i in industry]
 industry = list(set([i for i in industry if i not in rogue_words]))
 data[i]['industry'] = ', '.join(industry)
 industries.extend(industry)

print(industries)
create_wordcloud(industries, ['industry'])
{{increase}} {{US$|219.295 billion}} (2019)
{{Nowrap|Decrease| |US$|346.2 billion|ref| name="201310K"}} {{Decrease}} {{US$|346.2 billion}}
{{increase}} US$707.8 billion (2018)
{{Decrease}} {{US$|338.516&nbsp;billion}}
{{increase}} $173.889 billion (2019)
{{nowrap|increase| |US$|60.381 billion| |small|(2018)|ref| name=FY}} {{increase}} {{US$|60.381 billion}} {{small|(2018)}}
{{increase}} {{US$|196.456 billion}}
{{decrease}} {{US$|162.648 billion}}
{{increase}} {{US$|link|=|yes}} 531 billion     (2018)
{{increase}} US$227.339 billion {{small|(2018)}}
{{decrease}} {{US$|256.54 billion}} {{small|(2018)}}
{{increase}} {{US$|37.66 billion}} (2018)
{{decrease}} {{US$|253.9 billion}} {{small|(2018)}}
{{increase}} US$39.95 billion {{small|(2018)}}
{{increase}} US$45.40 billion
{{increase}} {{US$|264.82 billion}}
{{increase}} {{US$|38.11 billion}} (2019)
{{nowrap|Decrease| US$ 309.129 billion |small|(2018)}} {{Decrease}} US$ 309.129 billion {{small|(2018)}}
{{decrease}} {{US$|67.59 billion}}
{{increase}} [[United States dollar|US$]]2.687 [[trillion]]
regex1 = re.compile('([\d\.]+)')
regex2 = re.compile('(billion|trillion)')
assets = []
for i, x in enumerate(wiki_data):
 y = x['assets']
 z = regex1.findall(y)[0]
 unit = regex2.findall(y)[0]
 asset = float(z)
 data[i]['assets'] = str(asset) + ' ' + unit
 assets.append({'company' : x['company_name'], 'value' : asset, 'unit' : unit})

for i, asset in enumerate(assets):
 if asset['unit'] == 'trillion':
   assets[i]['value'] = asset['value'] * 1000
   assets[i]['unit'] = 'billion'

df_assets = pd.DataFrame(assets)
df_assets
ax = df_assets.plot(kind='bar',
 title ="Assets from the Top 20 Companies on Fortune 500",
 color='skyblue',
 figsize=(15, 10),
 legend=True,
 fontsize=12
 )
ax.set_xticklabels(df_assets.company)
ax.set_xlabel("Company Name", fontsize=12)
ax.set_ylabel("Assets (in Billions)", fontsize=12)
plt.show()

df_wiki = pd.DataFrame(data)
df_wiki.head()
df = pd.read_csv('fortune_500_companies.csv', nrows=20)
df = pd.concat([df, df_wiki], axis=1)
print(df)
df.to_csv('top_20_companies.csv', index=False)
import pandas as pd
import matplotlib.pyplot as plt
# Create a bar chart of equity for the top 20 Fortune 500 companies
plt.figure(figsize=(12, 6))
df_top20 = df.head(20)  # Assuming df is sorted by equity, adjust if needed
plt.bar(df_top20['name'], df_top20['revenue_mil'])
plt.xlabel('name')
plt.ylabel('revenue_mil')
plt.title('Top 20 Fortune 500 Companies by Equity')
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for better readability

# Display the plot
plt.show()

# Find out which company has the highest equity
max_revenue_mil_name = df.loc[df['revenue_mil'].idxmax()]['name']
print(f"The company with the highest equity is: {max_revenue_mil_name}")
# Out:
# {{hlist|Electronics|Movies and music|Home and furniture|Home improvement|Clothing|Footwear|Jewelry|Toys|Health and beauty|Pet supplies|Sporting goods and fitness|Auto|Photo finishing|Craft supplies|Party supplies|Grocery}}
#
#
# {{Unbulleted list
#   | [[Crude oil]]
#   | [[Oil products]]
#   | [[Natural gas]]
#   | [[Petrochemical]]s
#   | [[Power generation]]}}
#
#
# [[Investment|Diversified investments]], [[Insurance#Types|Property & casualty insurance]], [[Public utility|Utilities]], [[Restaurants]], [[Food processing]], [[Aerospace]], [[Toys]], [[Mass media|Media]], [[Automotive industry|Automotive]], [[Sports equipment|Sporting goods]], [[Final good|Consumer products]], [[Internet]], [[Real estate]]
#
#
# ['movies', 'finishing', 'party', 'grocery', 'sporting', 'footwear', 'craft', 'health', 'jewelry', 'supplies', 'beauty', 'toys', 'music', 'home', 'fitness', 'goods', 'improvement', 'clothing', 'auto', 'photo', 'pet', 'electronics', 'furniture', 'oil', 'crude', 'generation', 'products', 'list', 'gas', 'unbulleted', 'power', 'petrochemicals', 'natural', 'investments', 'food', 'estate', 'processing', 'consumer', 'internet', 'sports', 'utilities', 'public', 'aerospace', 'sporting', 'insurance', 'real', 'restaurants', 'investment', 'types', 'good', 'property', 'toys', 'casualty', 'final', 'products', 'goods', 'automotive', 'mass', 'industry', 'utility', 'diversified', 'media', 'equipment', 'tvos', 'iphone', 'cut', 'logic', 'watch', 'garageband', 'ipod', 'ilife', 'pro', 'ios', 'homepod', 'ipad', 'macos', 'iwork', 'ipados', 'final', 'shazam', 'siri', 'tv', 'macintosh', 'application', 'apple', 'watchos', 'services', 'uniprise', 'health', 'care', 'service', 'specialized', 'ingenix', 'economics', 'services', 'health', 'care', 'pharmaceuticals', 'technology', 'medical', 'fire', 'echo', 'tablet', 'tv', 'kindle', 'amazon', 'os', 'services', 'cable', 'service', 'internet', 'sports', 'provider', 'broadband', 'ott', 'publishing', 'line', 'video', 'digital', 'management', 'fixed', 'top', 'mobile', 'news', 'telephones', 'film', 'the', 'landline', 'security', 'phone', 'production', 'podcasts', 'home', 'agency', 'satellite', 'games', 'television', 'pay', 'filmmaking', 'media', 'iptv', 'network', 'over', 'automobiles', 'parts', 'commercial', 'automobile', 'car', 'vehicles', 'automotive', 'automobiles', 'auto', 'parts', 'commercial', 'of', 'list', 'trucks', 'pickup', 'suvs', 'unbulleted', 'car', 'luxury', 'vehicles', 'vehicle', 'services', 'pharmacy', 'pharmaceuticals', 'marketing', 'other', 'see', 'products', 'chevron', 'petroleum', 'gas', 'brands', 'petrochemicals', 'natural', 'pharmaceutical', 'services', 'products', 'medical', 'cable', 'of', 'things', 'landline', 'internet', 'mobile', 'phone', 'broadband', 'television', 'telematics', 'media', 'iptv', 'digital', 'other', 'superstore', 'supermarket', 'specialty', 'supercenter', 'turbines', 'health', 'energy', 'care', 'software', 'engines', 'electric', 'motors', 'lighting', 'finance', 'distribution', 'electrical', 'aircraft', 'power', 'wind', 'pharmacy', 'drug', 'store', 'estate', 'retail', 'commercial', 'mutual', 'digital', 'transfers', 'custodian', 'insurance', 'broker', 'bond', 'equity', 'prime', 'commodities', 'securities', 'financial', 'currency', 'exchange', 'loan', 'traded', 'default', 'backed', 'depositary', 'servicing', 'collateralized', 'services', 'pension', 'funding', 'markets', 'wholesale', 'foreign', 'capital', 'market', 'private', 'mobile', 'allocation', 'trading', 'hedge', 'debt', 'security', 'receipts', 'commodity', 'futures', 'lending', 'brokerage', 'derivative', 'treasury', 'risk', 'underwriting', 'index', 'trustee', 'wire', 'portfolio', 'wealth', 'analysis', 'funds', 'investor', 'mortgage', 'investing', 'money', 'lenders', 'planning', 'cards', 'swap', 'banking', 'institutional', 'information', 'american', 'settlement', 'portfolios', 'obligations', 'processing', 'stock', 'merchant', 'management', 'venture', 'investment', 'trader', 'asset', 'alternative', 'loans', 'brokers', 'remittance', 'subprime', 'finance', 'credit', 'brokering']
# [[Retail]]
# [[Energy industry|Energy]]: [[Oil and gas industry|Oil and gas]]
# [[Conglomerate (company)|Conglomerate]]
# {{Unbulleted list | [[Computer hardware]] | [[Computer software]] | [[Consumer electronics]] | [[Cloud computing]] | [[Digital distribution]] | [[Fabless manufacturing|Fabless silicon design]] | [[Semiconductors]] | [[Financial technology]] | [[Artificial intelligence]]}}
# [[Managed health care]]
# ['retail', 'gas', 'oil', 'energy', 'industry', 'company', 'conglomerate', 'consumer', 'list', 'intelligence', 'semiconductors', 'distribution', 'computing', 'technology', 'digital', 'silicon', 'cloud', 'artificial', 'financial', 'manufacturing', 'computer', 'hardware', 'design', 'software', 'fabless', 'electronics', 'unbulleted', 'managed', 'health', 'care', 'healthcare', 'retail', 'health', 'care', 'list', 'flat', 'e', 'stores', 'commerce', 'consumer', 'intelligence', 'grocery', 'electronics', 'cloud', 'distribution', 'artificial', 'computing', 'digital', 'mass', 'company', 'industry', 'list', 'telecommunications', 'media', 'entertainment', 'unbulleted', 'technology', 'automotive', 'industry', 'automotive', 'industry', 'pharmaceutical', 'oil', 'gas', 'industry', 'pharmaceuticals', 'retail', 'mass', 'telecommunications', 'media', 'industry', 'retail', 'company', 'conglomerate', 'pharmaceutical', 'retail', 'services', 'financial', 'banking']
#                                            name  rank  year  \
# 0                    General Motors Corporation     1  1996
# 1                            Ford Motor Company     2  1996
# 2                             Exxon Corporation     3  1996
# 3                         Wal-Mart Stores, Inc.     4  1996
# 4                                    AT&T Corp.     5  1996
# 5   International Business Machines Corporation     6  1996
# 6                      General Electric Company     7  1996
# 7                             Mobil Corporation     8  1996
# 8                          Chrysler Corporation     9  1996
# 9                       Philip Morris Companies    10  1996
# 10      Prudential Insurance Company of America    11  1996
# 11                             State Farm Group    12  1996
# 12    E.I. Du Pont de Nemours and Company, Inc.    13  1996
# 13                                 Texaco, Inc.    14  1996
# 14                     Sears, Roebuck & Company    15  1996
# 15                            Kmart Corporation    16  1996
# 16                 The Procter & Gamble Company    17  1996
# 17                          Chevron Corporation    18  1996
# 18                                     Citicorp    19  1996
# 19                      Hewlett-Packard Company    20  1996
#
#                                      industry  sector headquarters_state  \
# 0                      Motor Vehicles & Parts     NaN                 MI
# 1                      Motor Vehicles & Parts     NaN                 MI
# 2                          Petroleum Refining     NaN                 TX
# 3                       General Merchandisers     NaN                 AR
# 4                          Telecommunications     NaN                 NY
# 5                 Computers, Office Equipment     NaN                 NY
# 6           Electronics, Electrical Equipment     NaN                 CT
# 7                          Petroleum Refining     NaN                 VA
# 8                      Motor Vehicles & Parts     NaN                 MI
# 9                                     Tobacco     NaN                 NY
# 10           Insurance: Life, Health (Mutual)     NaN                 NJ
# 11  Insurance: Property and Casualty (Mutual)     NaN                 IL
# 12                                  Chemicals     NaN                 DE
# 13                         Petroleum Refining     NaN                 NY
# 14                      General Merchandisers     NaN                 IL
# 15                      General Merchandisers     NaN                 MI
# 16                           Soaps, Cosmetics     NaN                 OH
# 17                         Petroleum Refining     NaN                 CA
# 18                           Commercial Banks     NaN                 NY
# 19                Computers, Office Equipment     NaN                 CA
#
#     headquarters_city  market_value_mil  revenue_mil  profit_mil  asset_mil  \
# 0                 NaN               NaN     168828.6         NaN        NaN
# 1                 NaN               NaN     137137.0         NaN        NaN
# 2                 NaN               NaN     110009.0         NaN        NaN
# 3                 NaN               NaN      93627.0         NaN        NaN
# 4                 NaN               NaN      79609.0         NaN        NaN
# 5                 NaN               NaN      71940.0         NaN        NaN
# 6                 NaN               NaN      70028.0         NaN        NaN
# 7                 NaN               NaN      66724.0         NaN        NaN
# 8                 NaN               NaN      53195.0         NaN        NaN
# 9                 NaN               NaN      53139.0         NaN        NaN
# 10                NaN               NaN      41330.0         NaN        NaN
# 11                NaN               NaN      40809.9         NaN        NaN
# 12                NaN               NaN      37607.0         NaN        NaN
# 13                NaN               NaN      36787.0         NaN        NaN
# 14                NaN               NaN      35181.0         NaN        NaN
# 15                NaN               NaN      34654.0         NaN        NaN
# 16                NaN               NaN      33434.0         NaN        NaN
# 17                NaN               NaN      32094.0         NaN        NaN
# 18                NaN               NaN      31690.0         NaN        NaN
# 19                NaN               NaN      31519.0         NaN        NaN
#
#     employees  founder_is_ceo  female_ceo  newcomer_to_fortune_500  \
# 0         NaN             NaN         NaN                      NaN
# 1         NaN             NaN         NaN                      NaN
# 2         NaN             NaN         NaN                      NaN
# 3         NaN             NaN         NaN                      NaN
# 4         NaN             NaN         NaN                      NaN
# 5         NaN             NaN         NaN                      NaN
# 6         NaN             NaN         NaN                      NaN
# 7         NaN             NaN         NaN                      NaN
# 8         NaN             NaN         NaN                      NaN
# 9         NaN             NaN         NaN                      NaN
# 10        NaN             NaN         NaN                      NaN
# 11        NaN             NaN         NaN                      NaN
# 12        NaN             NaN         NaN                      NaN
# 13        NaN             NaN         NaN                      NaN
# 14        NaN             NaN         NaN                      NaN
# 15        NaN             NaN         NaN                      NaN
# 16        NaN             NaN         NaN                      NaN
# 17        NaN             NaN         NaN                      NaN
# 18        NaN             NaN         NaN                      NaN
# 19        NaN             NaN         NaN                      NaN
#
#     global_500                wiki_title  \
# 0          NaN                   Walmart
# 1          NaN                ExxonMobil
# 2          NaN        Berkshire Hathaway
# 3          NaN                Apple Inc.
# 4          NaN        UnitedHealth Group
# 5          NaN      McKesson Corporation
# 6          NaN                CVS Health
# 7          NaN          Amazon (company)
# 8          NaN                      AT&T
# 9          NaN            General Motors
# 10         NaN        Ford Motor Company
# 11         NaN         AmerisourceBergen
# 12         NaN       Chevron Corporation
# 13         NaN           Cardinal Health
# 14         NaN                    Costco
# 15         NaN    Verizon Communications
# 16         NaN                    Kroger
# 17         NaN          General Electric
# 18         NaN  Walgreens Boots Alliance
# 19         NaN            JPMorgan Chase
#
#                                               product  \
# 0   movies, finishing, party, grocery, sporting, f...
# 1   oil, crude, generation, products, list, gas, u...
# 2   investments, food, estate, processing, consume...
# 3   tvos, iphone, cut, logic, watch, garageband, i...
# 4   services, uniprise, health, care, service, spe...
# 5   services, health, care, pharmaceuticals, techn...
# 6
# 7          fire, echo, tablet, tv, kindle, amazon, os
# 8   services, cable, service, internet, sports, pr...
# 9   automobiles, parts, commercial, automobile, ca...
# 10  automotive, automobiles, auto, parts, commerci...
# 11                services, pharmacy, pharmaceuticals
# 12  marketing, other, see, products, chevron, petr...
# 13        pharmaceutical, services, products, medical
# 14
# 15  cable, of, things, landline, internet, mobile,...
# 16  other, superstore, supermarket, specialty, sup...
# 17  turbines, health, energy, care, software, engi...
# 18                              pharmacy, drug, store
# 19  estate, retail, commercial, mutual, digital, t...
#
#                                              industry           assets
# 0                                              retail  219.295 billion
# 1                          gas, oil, energy, industry    346.2 billion
# 2                               company, conglomerate    707.8 billion
# 3   consumer, list, intelligence, semiconductors, ...  338.516 billion
# 4                               managed, health, care  173.889 billion
# 5                                          healthcare   60.381 billion
# 6                    retail, health, care, list, flat  196.456 billion
# 7   e, stores, commerce, consumer, intelligence, g...  162.648 billion
# 8   mass, company, industry, list, telecommunicati...    531.0 billion
# 9                                automotive, industry  227.339 billion
# 10                               automotive, industry   256.54 billion
# 11                                     pharmaceutical    37.66 billion
# 12                                 oil, gas, industry    253.9 billion
# 13                                    pharmaceuticals    39.95 billion
# 14                                             retail     45.4 billion
# 15          mass, telecommunications, media, industry   264.82 billion
# 16                                             retail    38.11 billion
# 17                              company, conglomerate  309.129 billion
# 18                             pharmaceutical, retail    67.59 billion
# 19                       services, financial, banking   2.687 trillion
# The company with the highest equity is: General Motors Corporation
